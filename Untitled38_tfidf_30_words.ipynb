# %% [markdown]
# <a href="https://colab.research.google.com/github/mamta85/Git-hub-tutorial/blob/master/Untitled38_tfidf_30_words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import os

# Path to your cleaned review file
folder_path = '/content/drive/MyDrive/Health_Reviews'
file_path = os.path.join(folder_path, 'Combined_Cleaned_Reviews.csv')

# Load data
df = pd.read_csv(file_path)
print("✅ Data loaded:", df.shape)
df[['cleaned_content']].head()
# Install if needed
# !pip install scikit-learn

# Import TF-IDF tools
from sklearn.feature_extraction.text import TfidfVectorizer
# Create TF-IDF Vectorizer
tfidf_vectorizer = TfidfVectorizer(max_df=0.8, min_df=5, max_features=1000)

# Fit and transform on cleaned_content
tfidf_matrix = tfidf_vectorizer.fit_transform(df['cleaned_content'].astype(str))

# Get feature names (i.e., important words)
feature_names = tfidf_vectorizer.get_feature_names_out()

# Convert to DataFrame
import numpy as np
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names)

# Show TF-IDF scores (mean across documents)
mean_tfidf = tfidf_df.mean().sort_values(ascending=False)
mean_tfidf.head(20)
# Top 30 keywords indicating most common issues
top_issues = mean_tfidf.head(30)
top_issues_df = top_issues.reset_index()
top_issues_df.columns = ['Keyword', 'TF-IDF Score']
print("🔝 Top 30 Keywords (Issues):")
print(top_issues_df)
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
top_issues.plot(kind='bar', color='skyblue')
plt.title('Top 30 Keywords (User Issues via TF-IDF)')
plt.xlabel('Keyword')
plt.ylabel('Average TF-IDF Score')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
output_issues_path = os.path.join(folder_path, "Top_30_Issues_TFIDF.csv")
top_issues_df.to_csv(output_issues_path, index=False)
print(f"✅ Top issues saved to: {output_issues_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Data loaded: (124000, 9)
# ...
# 🔝 Top 30 Keywords (Issues):
#     Keyword  TF-IDF Score
# 0       app      0.081628
# 1       use      0.055335
# 2     great      0.054532
# 3      help      0.052014
# 4    remind      0.043942
# 5       med      0.042126
# 6      take      0.040210
# 7      good      0.035859
# 8      love      0.032432
# 9     medic      0.030639
# 10    track      0.030408
# 11     keep      0.029609
# 12     easi      0.028399
# 13     time      0.027573
# 14     work      0.026035
# 15     need      0.021343
# 16     like      0.019005
# 17   realli      0.018894
# 18     pill      0.016628
# 19    excel      0.015811
# 20    thank      0.015343
# 21     free      0.015036
# 22     best      0.014740
# 23  medicin      0.014277
# 24      day      0.013879
# 25   featur      0.013386
# 26    would      0.013312
# ...
